# %%
import json
import pandas as pd

# --- Load both files ---
with open('datasets_snapshot.json', 'r') as f:
    datasets_json = json.load(f)

with open('processes_snapshot_full.json', 'r') as f:
    processes_json = json.load(f)

# --- Extract useful info ---
datasets = []
for e in datasets_json.get("entities", []):
    attr = e.get("attributes", {})
    datasets.append({
        "Code": attr.get("name", "").split("]")[0].replace("[", "") if "[" in attr.get("name", "") else "",
        "Type": e.get("typeName"),
        "Name": attr.get("name"),
        "QualifiedName": attr.get("qualifiedName"),
        "Description": attr.get("description", "")
    })

processes = []
for e in processes_json.get("entities", []):
    attr = e.get("attributes", {})
    rel = e.get("relationshipAttributes", {})
    processes.append({
        "Code": attr.get("name", "").split("]")[0].replace("[", "") if "[" in attr.get("name", "") else "",
        "Type": e.get("typeName"),
        "Name": attr.get("name"),
        "QualifiedName": attr.get("qualifiedName"),
        "Description": attr.get("description", ""),
        "Inputs": ", ".join([inp.get("displayText", {}) for inp in rel.get("inputs", [])]) if rel.get("inputs") else "",
        "Outputs": ", ".join([out.get("displayText", {}) for out in rel.get("outputs", [])]) if rel.get("outputs") else ""
    })

# --- Combine and format ---
df_datasets = pd.DataFrame(datasets)
df_processes = pd.DataFrame(processes)
df_all = pd.concat([df_datasets, df_processes], ignore_index=True)

# --- Sort and export to Markdown ---
df_all = df_all[["Code", "Type", "Name", "QualifiedName", "Description", "Inputs", "Outputs"]]
df_all = df_all.sort_values(by="Code")

df_all = df_all[df_all["Code"]!=""]

df_all.to_csv("atlas_lineage.csv", index=False, encoding="utf-8")

markdown_table = df_all.to_markdown(index=False)
with open("atlas_entities_summary.md", "w") as f:
    f.write(markdown_table)

print("✅ Markdown summary saved as atlas_entities_summary.md")
# Out:
# 'markdown_table = df_all.to_markdown(index=False)\nwith open("atlas_entities_summary.md", "w") as f:\n    f.write(markdown_table)\n\nprint("✅ Markdown summary saved as atlas_entities_summary.md")\n'

# %%
display(df_all)
# Out:
#    Code     Type                                          Name  \
# 4    D1  DataSet                        [D1] - retail_data.csv
# 9   D10  DataSet              [D10] - API Flask remote (ngrok)
# 10  D11  DataSet            [D11] - retail_project_db_AzureSQL
# 13   D2  DataSet                        [D2] - customers_local
# 6    D3  DataSet                         [D3] - products_local
# 8    D4  DataSet                            [D4] - sales_local
# 11   D5  DataSet                   [D5] - retail_summary_local
# 2    D6  DataSet                          [D6] - agg_sales.csv
# 1    D7  DataSet                      [D7] - agg_customers.csv
# 5    D8  DataSet                        [D8] - API Flask local
# 12   D9  DataSet                     [D9] - almac101_container
# 23  P1a  Process                    [P1a]_import_sales_to_SSMS
# 18  P1b  Process                 [P1b] - export_customers_json
# 17  P1c  Process                 [P1c] - load_products_via_API
# 16  P1d  Process  [P1d] - consolidate_sales_customers_products
# 15   P2  Process                [P2] - export_sales_agg_to_csv
# 26   P3  Process            [P3] - export_customers_agg_to_csv
# 27   P4  Process             [P4] - export_products_agg_to_api
# 25   P5  Process                  [P5] - publish_through_ngrok
# 20   P6  Process                [P6] - ADF_pipeline_csv_to_SQL
# 19   P7  Process                [P7] - ADF_pipeline_API_to_SQL
#
#                                       QualifiedName  \
# 4                            retail_data.csv@retail
# 9                           api_flask_remote@retail
# 10                 retail_project_db_AzureSQL@azure
# 13                           customers_local@retail
# 6                             products_local@retail
# 8                                sales_local@retail
# 11                      retail_summary_local@retail
# 2                         agg_sales.csv@blobstorage
# 1                     agg_customers.csv@blobstorage
# 5                            api_flask_local@retail
# 12                   almac101_container@blobstorage
# 23                  P1a_import_sales_to_SSMS@retail
# 18                 P1b_export_customers_json@retail
# 17                 P1c_load_products_via_API@retail
# 16  P1d_consolidate_sales_customers_products@retail
# 15                P2_export_sales_agg_to_csv@retail
# 26            P3_export_customers_agg_to_csv@retail
# 27             P4_export_products_agg_to_api@retail
# 25                  P5_publish_through_ngrok@retail
# 20                P6_ADF_pipeline_csv_to_SQL@retail
# 19                P7_ADF_pipeline_API_to_SQL@retail
#
#                                           Description  \
# 4   original CSV from Kaggle with retail data (pri...
# 9   Remote Flask API exposed via ngrok tunnel, pro...
# 10  Final consolidated database in Azure SQL conta...
# 13  Customers table imported into SSMS (from retai...
# 6   Products table imported into SSMS (via API Fla...
# 8   Facts table 'sales' imported at SSMS from reta...
# 11  Final consolidated retail summary table (sales...
# 2   CSV with sales aggregated data exported from S...
# 1   CSV with aggregated customers data exported fr...
# 5   API Flask local exposes aggregated products da...
# 12  Azure Blob Storage container that stores the a...
# 23  Import 'sales' part/data from retail_data.csv ...
# 18  Extract customers from retail_data.csv to JSON...
# 17  Expose products via API Flask, consume and ins...
# 16  Join sales_local, customers_local, and product...
# 15  Export process over sales aggregation from SSM...
# 26  Export Process over customers aggregation from...
# 27  Process to publish products aggregated data fr...
# 25  Process that exposes the local Flask API (D8) ...
# 20  ADF pipeline to load aggregated CSV files into...
# 19  ADF pipeline to load aggregated data from remo...
#
#                                                Inputs  \
# 4                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 13                                                NaN
# 6                                                 NaN
# 8                                                 NaN
# 11                                                NaN
# 2                                                 NaN
# 1                                                 NaN
# 5                                                 NaN
# 12                                                NaN
# 23                             [D1] - retail_data.csv
# 18                             [D1] - retail_data.csv
# 17                             [D1] - retail_data.csv
# 16  [D2] - customers_local, [D3] - products_local,...
# 15                        [D5] - retail_summary_local
# 26                        [D5] - retail_summary_local
# 27                        [D5] - retail_summary_local
# 25                             [D8] - API Flask local
# 20     [D7] - agg_customers.csv, [D6] - agg_sales.csv
# 19                   [D10] - API Flask remote (ngrok)
#
#                                Outputs
# 4                                  NaN
# 9                                  NaN
# 10                                 NaN
# 13                                 NaN
# 6                                  NaN
# 8                                  NaN
# 11                                 NaN
# 2                                  NaN
# 1                                  NaN
# 5                                  NaN
# 12                                 NaN
# 23                  [D4] - sales_local
# 18              [D2] - customers_local
# 17               [D3] - products_local
# 16         [D5] - retail_summary_local
# 15                [D6] - agg_sales.csv
# 26            [D7] - agg_customers.csv
# 27              [D8] - API Flask local
# 25    [D10] - API Flask remote (ngrok)
# 20  [D11] - retail_project_db_AzureSQL
# 19  [D11] - retail_project_db_AzureSQL
