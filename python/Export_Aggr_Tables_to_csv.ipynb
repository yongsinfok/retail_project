# %%
import pandas as pd
import pyodbc

conn = pyodbc.connect("Driver={ODBC Driver 17 for SQL Server};Server=localhost\\SQLEXPRESS;Database=retail_project;Trusted_Connection=yes;")

df_category = pd.read_sql("SELECT * FROM agg_sales_by_category", conn)
df_category.to_csv(r"C:\Users\Eros\Documents\__Proyecto Integral__Retail\data_to_upload_through_Azure_Blob_Storage\agg_sales_by_category.csv", index=False)

df_country = pd.read_sql("SELECT * FROM agg_sales_by_country", conn)
df_country.to_csv(r"C:\Users\Eros\Documents\__Proyecto Integral__Retail\data_to_upload_through_Azure_Blob_Storage\agg_sales_by_country.csv", index=False)

conn.close()
# Out:
# C:\Users\Eros\AppData\Local\Temp\ipykernel_20112\1740131878.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_category = pd.read_sql("SELECT * FROM agg_sales_by_category", conn)
# C:\Users\Eros\AppData\Local\Temp\ipykernel_20112\1740131878.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_country = pd.read_sql("SELECT * FROM agg_sales_by_country", conn)
